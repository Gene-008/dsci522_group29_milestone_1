# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# %%
url = "https://cran.r-project.org/incoming/UL/diversedata/data-clean/hcmst.csv"
hcmst = pd.read_csv(url)

# %%
hcmst.head()
# Out:
#    subject_age subject_education subject_sex subject_ethnicity  \
# 0         53.0  high_school_grad      female             white
# 1         72.0      some_college      female             white
# 2         43.0  associate_degree        male             white
# 3         64.0      some_college        male             white
# 4         60.0  high_school_grad      female             black
#
#   subject_income_category subject_employment_status same_sex_couple  \
# 0                 35k_40k     working_paid_employee              no
# 1                 75k_85k     working_paid_employee              no
# 2                 75k_85k     working_paid_employee              no
# 3                 75k_85k     working_paid_employee              no
# 4                 75k_85k     working_paid_employee              no
#
#        married         sex_frequency   flirts_with_partner  ...  \
# 0  not_married  once_or_twice_a_week    a_few_times_a_week  ...
# 1      married  once_a_month_or_less                 never  ...
# 2      married  once_or_twice_a_week    a_few_times_a_week  ...
# 3      married  once_or_twice_a_week  1_to_3_times_a_month  ...
# 4      married  once_or_twice_a_week    a_few_times_a_week  ...
#
#   relationship_duration  children  rel_change_during_pandemic  \
# 0              1.500000       2.0          better_than_before
# 1             57.416668       1.0                   no_change
# 2             22.333334       5.0                   no_change
# 3             28.250000       2.0                   no_change
# 4             38.916668       3.0          better_than_before
#
#   inc_change_during_pandemic subject_had_covid partner_had_covid  \
# 0                  no_change                no               yes
# 1                      worse                no                no
# 2                      worse                no                no
# 3                  no_change                no                no
# 4                  no_change                no                no
#
#              subject_vaccinated            partner_vaccinated  \
# 0                not_vaccinated                not_vaccinated
# 1  fully_vaccinated_and_booster  fully_vaccinated_and_booster
# 2  fully_vaccinated_and_booster  fully_vaccinated_and_booster
# 3  fully_vaccinated_and_booster  fully_vaccinated_and_booster
# 4                not_vaccinated          partially_vaccinated
#
#   agree_covid_approach relationship_quality
# 0     completely_agree            excellent
# 1         mostly_agree                 good
# 2     completely_agree            excellent
# 3     completely_agree                 good
# 4     completely_agree            excellent
#
# [5 rows x 21 columns]

# %%
alt.Chart(hcmst).mark_bar().encode(
    x=alt.X('relationship_quality', title='Relationship Quality'),
    y='count()'
).properties(
    title='Distribution of Relationship Quality'
)
# Out:
# alt.Chart(...)

# %%
corr_mat = hcmst[['subject_age','relationship_duration', 'children']].corr()
sns.heatmap(corr_mat, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Relevant Predictor Variables')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Relevant Predictor Variables')

# %%
sns.countplot(x = 'subject_income_category', data = hcmst)
# Out:
# <Axes: xlabel='subject_income_category', ylabel='count'>

# %%
alt.Chart(hcmst).mark_bar().encode(
    x=alt.X('subject_income_category', title='Income Category'),
    y='count()'
).properties(
    title='Distribution of Income Category'
)
# Out:
# alt.Chart(...)
